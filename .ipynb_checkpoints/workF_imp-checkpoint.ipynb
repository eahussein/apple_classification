# %% [markdown]
# Hello, the flow of the work for this paper will be as follows:
# 1. read the data
# 2. scale the data
# 3. visualise the data
# 4. split the data
# 5. get feature importance (permutation)
# 6. visualize the best N imported features
# 7. try from (1, 5, 10, 50) best features
#     10, 20, 30, 40, 50 Freq. Random
# 8. the split should be (70, 30)
# 9. try up to 6 different classification models (RF, XGB, SVM, LR, KNNs, MD)
# 10. get the error bars and make comparisons

# %%
import pandas as pd # for importing data into data frame format
import seaborn as sns # For drawing useful graphs, such as bar graphs
from matplotlib.pyplot import show # This displays graphs once they have been created
import numpy as np
import matplotlib.pyplot as plt
from source.roc import draw_roc 
from scipy.stats import skew

# %% [markdown]
# ### 1. read the data

# %%
df = pd.read_excel('/users/hussein/source/apple_classification/data/Detect-GS.xlsx')

# %%
df.head(5)
# Out:
#                Sample Condition Age Source  11995.49  11991.63  11987.78  \
# 0  GS-ch-bruise1h-10a         B  1h     S1 -0.113748 -0.113815 -0.114197
# 1  GS-ch-bruise1h-10b         B  1h     S1 -0.161664 -0.161498 -0.161212
# 2  GS-ch-bruise1h-10c         S  1h     S1 -0.139064 -0.138784 -0.138928
# 3  GS-ch-bruise1h-10d         S  1h     S1 -0.143663 -0.143526 -0.143718
# 4  GS-ch-bruise1h-11a         B  1h     S1 -0.166998 -0.166739 -0.166921
#
#    11983.92  11980.06  11976.21  ...  4034.497   4030.64  4026.783  4022.926  \
# 0 -0.114321 -0.114032 -0.113495  ...  0.845574  0.850478  0.849688  0.844572
# 1 -0.161013 -0.160861 -0.160329  ...  0.428670  0.431408  0.433148  0.431059
# 2 -0.138786 -0.138244 -0.137692  ...  0.809659  0.808975  0.806819  0.805404
# 3 -0.143459 -0.142628 -0.142030  ...  0.682872  0.683971  0.688426  0.692536
# 4 -0.166882 -0.166638 -0.166418  ...  0.520031  0.521815  0.520814  0.518175
#
#    4019.069  4015.211  4011.354  4007.497   4003.64  3999.783
# 0  0.844248  0.849826  0.854541  0.849297  0.836767  0.830801
# 1  0.426104  0.422003  0.420373  0.419252  0.419077  0.421115
# 2  0.807540  0.810868  0.814169  0.812831  0.799328  0.783305
# 3  0.690982  0.685393  0.679534  0.677676  0.682072  0.689607
# 4  0.518827  0.523526  0.529133  0.532134  0.531992  0.529879
#
# [5 rows x 2078 columns]

# %%
df.shape
# Out:
# (503, 2078)

# %% [markdown]
# ### change the col names

# %%
wavenumbers = np.float_(df.columns[4:])
type(wavenumbers[0])
wavelengths = (1/wavenumbers)*10**7

print(str(wavenumbers[0])+", "+ str(wavelengths[0]))
# Out:
# 11995.49, 833.6466455309454

# %%
df.columns.values[4:] = np.round(wavelengths, 3)
df.head(4)
# Out:
#                Sample Condition Age Source   833.647   833.915   834.183  \
# 0  GS-ch-bruise1h-10a         B  1h     S1 -0.113748 -0.113815 -0.114197
# 1  GS-ch-bruise1h-10b         B  1h     S1 -0.161664 -0.161498 -0.161212
# 2  GS-ch-bruise1h-10c         S  1h     S1 -0.139064 -0.138784 -0.138928
# 3  GS-ch-bruise1h-10d         S  1h     S1 -0.143663 -0.143526 -0.143718
#
#     834.451    834.72   834.989  ...  2478.624  2480.996  2483.372  2485.753  \
# 0 -0.114321 -0.114032 -0.113495  ...  0.845574  0.850478  0.849688  0.844572
# 1 -0.161013 -0.160861 -0.160329  ...  0.428670  0.431408  0.433148  0.431059
# 2 -0.138786 -0.138244 -0.137692  ...  0.809659  0.808975  0.806819  0.805404
# 3 -0.143459 -0.142628 -0.142030  ...  0.682872  0.683971  0.688426  0.692536
#
#    2488.138  2490.529  2492.924  2495.323  2497.727  2500.136
# 0  0.844248  0.849826  0.854541  0.849297  0.836767  0.830801
# 1  0.426104  0.422003  0.420373  0.419252  0.419077  0.421115
# 2  0.807540  0.810868  0.814169  0.812831  0.799328  0.783305
# 3  0.690982  0.685393  0.679534  0.677676  0.682072  0.689607
#
# [4 rows x 2078 columns]

# %% [markdown]
# ### labels

# %%
ax = sns.countplot(x="Condition",data=df)

# %%
df['Condition'] = df['Condition'].str.upper()
ax = sns.countplot(x="Condition",data=df)

# %% [markdown]
# #### getting x, and y

# %%
df_input = df.iloc[:, 4: ]
df_input
# Out:
#      833.647   833.915   834.183   834.451   834.720   834.989   835.258   \
# 0   -0.113748 -0.113815 -0.114197 -0.114321 -0.114032 -0.113495 -0.113074
# 1   -0.161664 -0.161498 -0.161212 -0.161013 -0.160861 -0.160329 -0.159698
# 2   -0.139064 -0.138784 -0.138928 -0.138786 -0.138244 -0.137692 -0.137664
# 3   -0.143663 -0.143526 -0.143718 -0.143459 -0.142628 -0.142030 -0.142162
# 4   -0.166998 -0.166739 -0.166921 -0.166882 -0.166638 -0.166418 -0.166405
# ..        ...       ...       ...       ...       ...       ...       ...
# 498 -0.005843 -0.005746 -0.005965 -0.006040 -0.005732 -0.005905 -0.006496
# 499 -0.010555 -0.009949 -0.010038 -0.010154 -0.010212 -0.010717 -0.010729
# 500 -0.054230 -0.054836 -0.055471 -0.055616 -0.055853 -0.056578 -0.056854
# 501  0.052804  0.052833  0.053037  0.053045  0.052818  0.052379  0.052130
# 502  0.041177  0.041673  0.042308  0.043298  0.043552  0.042483  0.041469
#
#      835.527   835.796   836.066   ...  2478.624  2480.996  2483.372  \
# 0   -0.113266 -0.114108 -0.114498  ...  0.845574  0.850478  0.849688
# 1   -0.159639 -0.160184 -0.160504  ...  0.428670  0.431408  0.433148
# 2   -0.138295 -0.139098 -0.139391  ...  0.809659  0.808975  0.806819
# 3   -0.142754 -0.143336 -0.143301  ...  0.682872  0.683971  0.688426
# 4   -0.166787 -0.167322 -0.167319  ...  0.520031  0.521815  0.520814
# ..        ...       ...       ...  ...       ...       ...       ...
# 498 -0.006305 -0.005184 -0.004249  ...  0.823532  0.825095  0.831351
# 499 -0.009878 -0.009303 -0.009316  ...  0.647229  0.642954  0.642807
# 500 -0.055983 -0.054825 -0.054404  ...  0.403613  0.404402  0.408775
# 501  0.052272  0.052694  0.053489  ...  1.357465  1.369164  1.395378
# 502  0.041463  0.041921  0.042606  ...  1.222870  1.235548  1.237530
#
#      2485.753  2488.138  2490.529  2492.924  2495.323  2497.727  2500.136
# 0    0.844572  0.844248  0.849826  0.854541  0.849297  0.836767  0.830801
# 1    0.431059  0.426104  0.422003  0.420373  0.419252  0.419077  0.421115
# 2    0.805404  0.807540  0.810868  0.814169  0.812831  0.799328  0.783305
# 3    0.692536  0.690982  0.685393  0.679534  0.677676  0.682072  0.689607
# 4    0.518175  0.518827  0.523526  0.529133  0.532134  0.531992  0.529879
# ..        ...       ...       ...       ...       ...       ...       ...
# 498  0.830832  0.824308  0.817157  0.814575  0.815848  0.817096  0.823652
# 499  0.646312  0.650215  0.651266  0.648941  0.648903  0.655380  0.662244
# 500  0.410042  0.406809  0.405787  0.406463  0.405325  0.406469  0.410188
# 501  1.412128  1.423115  1.429553  1.404126  1.366339  1.349845  1.325851
# 502  1.227762  1.227575  1.243092  1.256490  1.253278  1.236511  1.222096
#
# [503 rows x 2074 columns]

# %%
y = df['Condition']

# %% [markdown]
# ### 2.scale the data

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# input_scaled = scaler.fit_transform(df_input)

# df_input_scaled = pd.DataFrame(input_scaled, columns = df_input.columns)
# # df_input_scaled['class'] = df['Condition']

# df_input_scaled

# %% [markdown]
# ### 3. visualize the data

# %%
n = 100
target = np.array(df['Condition'])
rand  = np.random.randint(len(target), size= n)
rand
# Out:
# array([110, 135, 175, 103, 171, 120,  75,  36, 147, 202,  56, 424, 333,
#        274, 280,  89, 372, 233, 334,  93,   6, 164, 113, 502, 379, 278,
#        302, 295, 257, 500, 167,  24, 138, 252, 158, 248, 149, 412, 433,
#        207, 234, 381, 496, 297, 102, 337, 380, 433,  38, 485,   4, 224,
#        282, 282, 252, 127, 344, 355, 191, 491,   3, 228,  60, 308, 475,
#        195, 222, 115, 149, 293, 306, 104,   0,  47, 468,  35,  41, 169,
#        202,  75, 458, 454, 364, 380, 124, 101,  25, 389, 102, 423, 266,
#        287, 465,  56,  10, 431, 399, 283,  27, 182])

# %%
for t in range (n):
    i = rand[t]
    lineSpec =  np.array(df_input.iloc[i]).flatten()
    if target[i] == 'S':
        plt.plot(np.array(df_input.columns), lineSpec, color = 'red')
    if target[i] == 'B':
        plt.plot(np.array(df_input.columns), lineSpec, color = 'blue')
    # plt.ylim(-1, 2)
plt.show()

# for t in range (n):
#     i = rand[t]
#     lineSpec =  np.array(df_input.iloc[i]).flatten()
#     if target[i] == 'S':
#         plt.scatter(t, np.mean(lineSpec), color = 'red')
#     if target[i] == 'B':
#         plt.scatter(t, np.mean(lineSpec), color = 'blue')
#     # plt.ylim(-1, 2)
# plt.show()

# for t in range (n):
#     i = rand[t]
#     lineSpec =  np.array(df_input.iloc[i]).flatten()
#     if target[i] == 'S':
#         plt.scatter(t, np.median(lineSpec), color = 'red')
#     if target[i] == 'B':
#         plt.scatter(t, np.median(lineSpec), color = 'blue')
#     # plt.ylim(-1, 2)
# plt.show()

# for t in range (n):
#     i = rand[t]
#     lineSpec =  np.array(df_input_scaled.iloc[i]).flatten()
#     if target[i] == 'S':
#         plt.scatter(np.median(lineSpec), skew(lineSpec), color = 'red')
#     if target[i] == 'B':
#         plt.scatter(np.median(lineSpec), skew(lineSpec), color = 'blue')
#     # plt.ylim(-1, 2)
# plt.show()

# %%
plt.plot(df_input.columns, df_input.values.mean(0), color = 'red')

# %%
# for t in range (n):
#     i = rand[t]
#     lineSpec =  np.array(df_input.iloc[i]).flatten()
#     # if target[i] == 'S':
#     #     plt.plot(np.array(df_input.columns), lineSpec, color = 'red')
#     if target[i] == 'B':
#         plt.plot(np.array(df_input.columns), lineSpec, color = 'blue')
#     plt.ylim(-1, 2)
# plt.show()
# first 2, and local min and max

# %% [markdown]
# ### 4. split the data

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, Ytrain, Ytest = train_test_split( df_input, y, test_size = 0.3, random_state=3, stratify=y) # train and valid sets

# %%
print(Xtrain.shape)
print(Xtest.shape)
# Out:
# (352, 2074)
# (151, 2074)

# %% [markdown]
# ### 5- permutation_importance

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
from random import *
import random
from matplotlib import pyplot

attrNames = np.array(df_input.columns)
attrNames
# Out:
# array([833.647, 833.915, 834.183, ..., 2495.323, 2497.727, 2500.136],
#       dtype=object)

# %%
featureImport = []

# %%
for i in range (1000): # take the average of 3 permutations, with different sizes and random splits (you can increase the number for it to be more robust)
    print("itr: " + str(i))
    
    RandomStateValid = randrange(50)
    ranodmSplitValid = random.uniform(0.2, 0.5)
    XtrainPer, XvalidPer, YtrainPer, YvalidPer = train_test_split( np.array(Xtrain), np.array(Ytrain), test_size = ranodmSplitValid, random_state=RandomStateValid, stratify=Ytrain) # train and valid sets
    print("Train shape: "+str(XtrainPer.shape))
    print("Valid shape: "+str(XvalidPer.shape))
    print()
   
    # train
    model = RandomForestClassifier(n_estimators=50, random_state=0, n_jobs = -1)
    model.fit(XtrainPer, YtrainPer)
    
    results = permutation_importance(model, XvalidPer, YvalidPer, scoring='precision_macro', n_repeats = 10, n_jobs = -1)
    importance = results.importances_mean
    # print(importance)

    featureImport.append(importance)
# Out:
# itr: 0
# Train shape: (187, 2074)
# Valid shape: (165, 2074)
#
# itr: 1
# Train shape: (250, 2074)
# Valid shape: (102, 2074)
#
# itr: 2
# Train shape: (247, 2074)
# Valid shape: (105, 2074)
#
# itr: 3
# Train shape: (185, 2074)
# Valid shape: (167, 2074)
#
# itr: 4
# Train shape: (209, 2074)
# Valid shape: (143, 2074)
#
# itr: 5
# Train shape: (182, 2074)
# Valid shape: (170, 2074)
#
# itr: 6
# Train shape: (186, 2074)
# Valid shape: (166, 2074)
#
# itr: 7
# Train shape: (258, 2074)
# Valid shape: (94, 2074)
#
# itr: 8
# Train shape: (220, 2074)
# Valid shape: (132, 2074)
#
# itr: 9
# Train shape: (192, 2074)
# Valid shape: (160, 2074)
#
# itr: 10
# Train shape: (206, 2074)
# Valid shape: (146, 2074)
#
# itr: 11
# Train shape: (254, 2074)
# Valid shape: (98, 2074)
#
# itr: 12
# Train shape: (214, 2074)
# Valid shape: (138, 2074)
#
# itr: 13
# Train shape: (245, 2074)
# Valid shape: (107, 2074)
#
# itr: 14
# Train shape: (215, 2074)
# Valid shape: (137, 2074)
#
# itr: 15
# Train shape: (182, 2074)
# Valid shape: (170, 2074)
#
# itr: 16
# Train shape: (183, 2074)
# Valid shape: (169, 2074)
#
# itr: 17
# Train shape: (275, 2074)
# Valid shape: (77, 2074)
#
# itr: 18
# Train shape: (192, 2074)
# Valid shape: (160, 2074)
#
# itr: 19
# Train shape: (246, 2074)
# Valid shape: (106, 2074)
#
# itr: 20
# Train shape: (274, 2074)
# Valid shape: (78, 2074)
#
# itr: 21
# Train shape: (184, 2074)
# Valid shape: (168, 2074)
#
# itr: 22
# Train shape: (218, 2074)
# Valid shape: (134, 2074)
#
# itr: 23
# Train shape: (240, 2074)
# Valid shape: (112, 2074)
#
# itr: 24
# Train shape: (227, 2074)
# Valid shape: (125, 2074)
#
# itr: 25
# Train shape: (179, 2074)
# Valid shape: (173, 2074)
#
# itr: 26
# Train shape: (275, 2074)
# Valid shape: (77, 2074)
#
# itr: 27
# Train shape: (221, 2074)
# Valid shape: (131, 2074)
#
# itr: 28
# Train shape: (273, 2074)
# Valid shape: (79, 2074)
#
# itr: 29
# Train shape: (209, 2074)
# Valid shape: (143, 2074)
#
# itr: 30
# Train shape: (200, 2074)
# Valid shape: (152, 2074)
#
# itr: 31
# Train shape: (249, 2074)
# Valid shape: (103, 2074)
#
# itr: 32
# Train shape: (234, 2074)
# Valid shape: (118, 2074)
#
# itr: 33
# Train shape: (261, 2074)
# Valid shape: (91, 2074)
#
# itr: 34
# Train shape: (232, 2074)
# Valid shape: (120, 2074)
#
# itr: 35
# Train shape: (196, 2074)
# Valid shape: (156, 2074)
#
# itr: 36
# Train shape: (217, 2074)
# Valid shape: (135, 2074)
#
# itr: 37
# Train shape: (254, 2074)
# Valid shape: (98, 2074)
#
# itr: 38
# Train shape: (217, 2074)
# Valid shape: (135, 2074)
#
# itr: 39
# Train shape: (244, 2074)
# Valid shape: (108, 2074)
#
# itr: 40
# Train shape: (270, 2074)
# Valid shape: (82, 2074)
#
# itr: 41
# Train shape: (188, 2074)
# Valid shape: (164, 2074)
#
# itr: 42
# Train shape: (210, 2074)
# Valid shape: (142, 2074)
#
# itr: 43
# Train shape: (272, 2074)
# Valid shape: (80, 2074)
#
# itr: 44
# Train shape: (208, 2074)
# Valid shape: (144, 2074)
#
# itr: 45
# Train shape: (257, 2074)
# Valid shape: (95, 2074)
#
# itr: 46
# Train shape: (189, 2074)
# Valid shape: (163, 2074)
#
# itr: 47
# Train shape: (247, 2074)
# Valid shape: (105, 2074)
#
# itr: 48
# Train shape: (177, 2074)
# Valid shape: (175, 2074)
#
# itr: 49
# Train shape: (220, 2074)
# Valid shape: (132, 2074)
#
# itr: 50
# Train shape: (204, 2074)
# Valid shape: (148, 2074)
#
# itr: 51
# Train shape: (251, 2074)
# Valid shape: (101, 2074)
#
# itr: 52
# Train shape: (218, 2074)
# Valid shape: (134, 2074)
#
# itr: 53
# Train shape: (226, 2074)
# Valid shape: (126, 2074)
#
# itr: 54
# Train shape: (256, 2074)
# Valid shape: (96, 2074)
#
# itr: 55
# Train shape: (221, 2074)
# Valid shape: (131, 2074)
#
# itr: 56
# Train shape: (211, 2074)
# Valid shape: (141, 2074)
#
# itr: 57
# Train shape: (195, 2074)
# Valid shape: (157, 2074)
#
# itr: 58
# Train shape: (252, 2074)
# Valid shape: (100, 2074)
#
# itr: 59
# Train shape: (275, 2074)
# Valid shape: (77, 2074)
#
# itr: 60
# Train shape: (281, 2074)
# Valid shape: (71, 2074)
#
# itr: 61
# Train shape: (250, 2074)
# Valid shape: (102, 2074)
#
# itr: 62
# Train shape: (224, 2074)
# Valid shape: (128, 2074)
#
# itr: 63
# Train shape: (211, 2074)
# Valid shape: (141, 2074)
#
# itr: 64
# Train shape: (203, 2074)
# Valid shape: (149, 2074)
#
# itr: 65
# Train shape: (213, 2074)
# Valid shape: (139, 2074)
#
# itr: 66
# Train shape: (276, 2074)
# Valid shape: (76, 2074)
#
# itr: 67
# Train shape: (281, 2074)
# Valid shape: (71, 2074)
#
# itr: 68
# Train shape: (271, 2074)
# Valid shape: (81, 2074)
#
# itr: 69
# Train shape: (240, 2074)
# Valid shape: (112, 2074)
#
# itr: 70
# Train shape: (222, 2074)
# Valid shape: (130, 2074)

# %%
print(np.array(featureImport).shape)

arrimp = np.array(featureImport).mean(0)
print(arrimp.shape)
print(arrimp)
print()
sorted_idx = arrimp.argsort()

print("sorted")
print((arrimp[sorted_idx]))
# print(attrNames[sorted_idx])
# Out:
# (1000, 2074)
# (2074,)
# [ 8.95578460e-05  1.81557357e-04  1.03030160e-04 ... -9.90078322e-05
#   9.57412325e-05 -2.54702442e-04]
#
# sorted
# [-0.00036524 -0.0002547  -0.00021976 ...  0.00027055  0.00034297
#   0.00050396]

# %% [markdown]
# #### store the index of the most N important features

# %%
# featOrdered = attrNames[sorted_idx][-400:]
# %store featOrdered
# %store sorted_idx
# %store arrimp

# %%
# %store -r featOrdered
# %store -r sorted_idx
# %store -r arrimp

# %% [markdown]
# ---

# %%
plt.hist(arrimp[sorted_idx])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 plt.hist(arrimp[sorted_idx])
#       2 plt.show()
#
# NameError: name 'arrimp' is not defined

# %%
n = 50

pyplot.rcParams["figure.figsize"] = (15,10)# 'xtick.labelsize', 'ytick.labelsize'
pyplot.rcParams['ytick.labelsize'] = (15)# 'xtick.labelsize', 'ytick.labelsize'
pyplot.rcParams['xtick.labelsize'] = (15)# 'xtick.labelsize', 'ytick.labelsize'
pyplot.rcParams['axes.labelsize'] = 15
pyplot.rcParams['axes.titlesize'] = 15


# print(attrNames[sorted_idx][-n:])
# print(arrimp[sorted_idx][-n:])

pyplot.scatter(attrNames[sorted_idx][-n:], arrimp[sorted_idx][-n:], color = 'blue')
# pyplot.scatter(attrNames[sorted_idx][:n], arrimp[sorted_idx][:n], color= 'red')

# pyplot.barh(np.arange(0, n), arrimp[sorted_idx][-n:])

# # pyplot.barh(range(10), arrimp[10:])

pyplot.show()
# peaks are important.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 13>()
#       7 pyplot.rcParams['axes.titlesize'] = 15
#      10 # print(attrNames[sorted_idx][-n:])
#      11 # print(arrimp[sorted_idx][-n:])
# ---> 13 pyplot.scatter(attrNames[sorted_idx][-n:], arrimp[sorted_idx][-n:], color = 'blue')
#      14 # pyplot.scatter(attrNames[sorted_idx][:n], arrimp[sorted_idx][:n], color= 'red')
#      15
#      16 # pyplot.barh(np.arange(0, n), arrimp[sorted_idx][-n:])
#      17
#      18 # # pyplot.barh(range(10), arrimp[10:])
#      20 pyplot.show()
#
# NameError: name 'arrimp' is not defined

# %% [markdown]
# ### 6- visualise best 10 features

# %%
df_perImp = pd.DataFrame()
df_perImp = df_input_scaled[attrNames[sorted_idx][-10:]]
df_perImp['Condition'] = df['Condition'].values
print(df_perImp)
# Out:
#       8732.41  5272.617  11964.64  10468.09  10167.24  8635.983  8643.697  \
# 0   -0.557443 -0.399727 -0.814925 -0.655486 -0.634020 -0.520118 -0.520954
# 1   -1.025889 -1.926705 -1.042774 -1.012756 -1.004210 -1.039594 -1.039149
# 2   -0.884907 -0.483883 -0.938503 -0.915875 -0.906818 -0.862816 -0.863498
# 3   -0.923287 -0.991572 -0.959460 -0.938812 -0.934839 -0.913527 -0.913660
# 4   -1.188785 -1.610837 -1.078072 -1.137343 -1.159048 -1.225084 -1.223596
# ..        ...       ...       ...       ...       ...       ...       ...
# 498 -0.396244 -0.344851 -0.276278 -0.377731 -0.364606 -0.397989 -0.398778
# 499 -0.525676 -1.070618 -0.296644 -0.437446 -0.431786 -0.562057 -0.562703
# 500 -0.764794 -2.022469 -0.521762 -0.661161 -0.635829 -0.813049 -0.812325
# 501 -0.082315  1.476153  0.009937 -0.081010 -0.071069 -0.077834 -0.079749
# 502 -0.190473  1.192609 -0.043338 -0.178329 -0.172312 -0.182131 -0.183137
#
#      8682.268  11586.64  11764.07 Condition
# 0   -0.528655 -0.810358 -0.809302         B
# 1   -1.033522 -1.040917 -1.040610         B
# 2   -0.869899 -0.931106 -0.932608         S
# 3   -0.916167 -0.960547 -0.959083         S
# 4   -1.210880 -1.080047 -1.079472         B
# ..        ...       ...       ...       ...
# 498 -0.400048 -0.290509 -0.285219         S
# 499 -0.555673 -0.317215 -0.310294         S
# 500 -0.801691 -0.538508 -0.529644         B
# 501 -0.084366  0.004768  0.008611         S
# 502 -0.188775 -0.058626 -0.050110         S
#
# [503 rows x 11 columns]
# /tmp/ipykernel_4125655/24525081.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_perImp['Condition'] = df['Condition'].values

# %%
sns.set(font_scale=2)
sns.pairplot(df_perImp, hue="Condition")
