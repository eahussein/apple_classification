# %% [markdown]
# # Tutorial 9: addition on the best 400 features

# %% [markdown]
# ---

# %% [markdown]
# ### Introduction

# %% [markdown]
# Hello, this notebook will show how to use sequential adding to perform further feature selection, as we found that most features are very highly correlated, therfore we would need to remove those using the tool that we mentioned above.

# %% [markdown]
# first, let us call the data

# %%
# %store -r df_input_GD
# %store -r y_GD
# %store -r df_GD

# %%
y_GD = y_GD.map({'S': 1, 'B': 0})

# %% [markdown]
# ---

# %% [markdown]
# calling some packages

# %%
# Python packages 
import pandas as pd # for importing data into data frame format
import seaborn as sns # For drawing useful graphs, such as bar graphs
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# <b><i> Data splitting </i></b>

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, Ytrain, Ytest = train_test_split( df_input_GD, y_GD, test_size = 0.3, random_state=3, stratify=y_GD) # train and valid sets

# %%
print(Xtrain.shape)
print(Xtest.shape)
# Out:
# (382, 2074)
# (165, 2074)

# %% [markdown]
# ---

# %% [markdown]
# <b><i> get the best N features </i></b>

# %%
# %store -r featImp_GD

# %%
arrimp = np.array(featImp_GD).mean(0)
sorted_idx = arrimp.argsort()
print(sorted_idx[-10:])
# Out:
# [ 15 205 144 153  71 180 157  60  43  86]

# %%
cols_ordered = df_input_GD.columns[sorted_idx][-400:]
cols_ordered
# Out:
# Index([1018.719,  883.052, 1229.322,   989.18,  919.703, 2450.511, 1663.015,
#          975.41,  1551.55, 2002.039,
#        ...
#         837.687,  892.475,  874.121,  876.781,  853.123,   884.86,  877.969,
#         850.046,  845.334,  857.355],
#       dtype='object', length=400)

# %% [markdown]
# ---

# %%
Xtrain[cols_ordered]
# Out:
#      1018.719  883.052   1229.322  989.180   919.703   2450.511  1663.015  \
# 228 -1.087990 -1.030926 -1.148293 -1.113318 -1.048227 -0.685276 -1.092314
# 474  1.300795  1.238410  1.339526  1.304189  1.260066  0.935879  1.344952
# 273  1.150353  1.146772  1.144389  1.152049  1.143321  0.655422  1.082083
# 285  0.908300  1.006635  0.788019  0.879218  0.985668  0.156375  0.599963
# 20  -0.762880 -0.789648 -0.669492 -0.734424 -0.783509  0.021936 -0.357177
# ..        ...       ...       ...       ...       ...       ...       ...
# 391  1.267932  1.262031  1.286273  1.269223  1.266144  1.333936  1.362730
# 71  -0.988367 -0.964915 -0.996997 -0.994270 -0.962605  0.076077 -0.790307
# 287  1.158114  1.096258  1.181571  1.176683  1.108657  0.086486  0.903432
# 66  -1.341772 -1.283949 -1.473712 -1.379037 -1.292361 -1.654704 -1.660482
# 85  -1.055156 -1.026815 -1.080390 -1.044240 -1.028090 -1.058400 -1.120412
#
#      975.410   1551.550  2002.039  ...  837.687   892.475   874.121   \
# 228 -1.117591 -0.997408 -0.649178  ... -1.040947 -1.035275 -1.030146
# 474  1.303722  1.300464  1.024498  ...  1.210396  1.244742  1.230255
# 273  1.157107  1.084859  0.807275  ...  1.127660  1.141946  1.144145
# 285  0.877727  0.541269  0.227356  ...  1.017840  1.000981  1.012044
# 20  -0.721339 -0.196387  0.022215  ... -0.797608 -0.788356 -0.792682
# ..        ...       ...       ...  ...       ...       ...       ...
# 391  1.273116  1.383025  1.328693  ...  1.240678  1.262327  1.258593
# 71  -0.989817 -0.598052  0.041415  ... -0.981073 -0.963380 -0.965990
# 287  1.182322  0.697978  0.130295  ...  1.088064  1.103508  1.098137
# 66  -1.387514 -1.700697 -1.668134  ... -1.292153 -1.282100 -1.279279
# 85  -1.034055 -1.136569 -1.104175  ... -1.024621 -1.025982 -1.027971
#
#      876.781   853.123   884.860   877.969   850.046   845.334   857.355
# 228 -1.033481 -1.032521 -1.034466 -1.029368 -1.031805 -1.039755 -1.031936
# 474  1.231594  1.220015  1.233132  1.230056  1.216652  1.215678  1.224416
# 273  1.144791  1.137959  1.144632  1.144275  1.139449  1.133384  1.144581
# 285  1.010621  1.020728  1.009804  1.008720  1.020247  1.022598  1.018547
# 20  -0.789674 -0.799611 -0.786075 -0.790533 -0.802299 -0.794386 -0.800824
# ..        ...       ...       ...       ...       ...       ...       ...
# 391  1.259826  1.246070  1.264388  1.259422  1.246331  1.244710  1.247542
# 71  -0.963353 -0.978024 -0.959486 -0.964945 -0.978210 -0.975422 -0.977062
# 287  1.097991  1.090781  1.102332  1.098439  1.096154  1.096031  1.091843
# 66  -1.279909 -1.284921 -1.277541 -1.281256 -1.285772 -1.282308 -1.285889
# 85  -1.025618 -1.028104 -1.024180 -1.028601 -1.025806 -1.022977 -1.030241
#
# [382 rows x 400 columns]

# %% [markdown]
# ### SFS

# %%
# explore the number of selected features for RFE
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.pipeline import Pipeline
from matplotlib import pyplot
from sklearn.linear_model import LogisticRegression

# %%
# https://machinelearningmastery.com/rfe-feature-selection-in-python/
selected = []
imp_ind = []
imp_freq = []

for i in range(1, 51, 1):
    print(i)
    sfs = SequentialFeatureSelector(estimator=LogisticRegression(solver = 'newton-cg'), n_features_to_select=i, direction = 'forward')
    # fit sfs
    sfs.fit(Xtrain[cols_ordered].values, Ytrain)
    # summarize all features
    selected_feat = []
    for i in range(Xtrain[cols_ordered].shape[1]):
        if sfs.support_[i] == True:
            selected_feat.append(i)
            print('Column: %d, Selected %s,' % (i, sfs.support_[i]))
        
    # print()
    selected.append(selected_feat)
    
    result = list(set(imp_ind) ^ set(selected[-1]))
    imp_freq.extend(Xtrain[cols_ordered].columns[result])    
    imp_ind.extend(result)    
    
    print(selected[-1])
    print(result)
    print(imp_ind)
    print(imp_freq)
    print()
# Out:
# 1
# Column: 371, Selected True,
# [371]
# [371]
# [371]
# [1394.643]
#
# 2
# Column: 38, Selected True,
# Column: 371, Selected True,
# [38, 371]
# [38]
# [371, 38]
# [1394.643, 2130.354]
#
# 3
# Column: 38, Selected True,
# Column: 99, Selected True,
# Column: 371, Selected True,
# [38, 99, 371]
# [99]
# [371, 38, 99]
# [1394.643, 2130.354, 883.353]
#
# 4
# Column: 38, Selected True,
# Column: 99, Selected True,
# Column: 201, Selected True,
# Column: 371, Selected True,
# [38, 99, 201, 371]
# [201]
# [371, 38, 99, 201]
# [1394.643, 2130.354, 883.353, 1365.266]
#
# 5
# Column: 38, Selected True,
# Column: 99, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 371, Selected True,
# [38, 99, 177, 201, 371]
# [177]
# [371, 38, 99, 201, 177]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929]
#
# 6
# Column: 1, Selected True,
# Column: 38, Selected True,
# Column: 99, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 371, Selected True,
# [1, 38, 99, 177, 201, 371]
# [1]
# [371, 38, 99, 201, 177, 1]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052]
#
# 7
# Column: 1, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 99, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 371, Selected True,
# [1, 38, 40, 99, 177, 201, 371]
# [40]
# [371, 38, 99, 201, 177, 1, 40]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203]
#
# 8
# Column: 1, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 99, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 371, Selected True,
# [1, 38, 40, 99, 148, 177, 201, 371]
# [148]
# [371, 38, 99, 201, 177, 1, 40, 148]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597]
#
# 9
# Column: 1, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 99, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [1, 38, 40, 99, 148, 177, 201, 232, 371]
# [232]
# [371, 38, 99, 201, 177, 1, 40, 148, 232]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597]
#
# 10
# Column: 1, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [1, 38, 40, 86, 99, 148, 177, 201, 232, 371]
# [86]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095]
#
# 11
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [1, 3, 38, 40, 86, 99, 148, 177, 201, 232, 371]
# [3]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18]
#
# 12
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [1, 3, 21, 38, 40, 86, 99, 148, 177, 201, 232, 371]
# [21]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503]
#
# 13
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 21, 38, 40, 86, 99, 148, 177, 201, 232, 371]
# [0]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719]
#
# 14
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 21, 38, 40, 86, 99, 136, 148, 177, 201, 232, 371]
# [136]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608]
#
# 15
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 61, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 21, 38, 40, 61, 86, 99, 136, 148, 177, 201, 232, 371]
# [61]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449]
#
# 16
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 61, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 21, 38, 40, 61, 86, 99, 136, 148, 177, 201, 232, 371]
# [5]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511]
#
# 17
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 21, 38, 40, 61, 85, 86, 99, 136, 148, 177, 201, 232, 371]
# [85]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798]
#
# 18
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 21, 38, 40, 61, 85, 86, 99, 101, 136, 148, 177, 201, 232, 371]
# [101]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465]
#
# 19
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 21, 38, 40, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [117]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898]
#
# 20
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 7, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 7, 21, 38, 40, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [7]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117, 7]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898, 975.41]
#
# 21
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 7, Selected True,
# Column: 13, Selected True,
# Column: 21, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 7, 13, 21, 38, 40, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [13]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117, 7, 13]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898, 975.41, 2160.534]
#
# 22
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 7, Selected True,
# Column: 13, Selected True,
# Column: 21, Selected True,
# Column: 23, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 7, 13, 21, 23, 38, 40, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [23]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117, 7, 13, 23]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898, 975.41, 2160.534, 973.579]
#
# 23
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 7, Selected True,
# Column: 13, Selected True,
# Column: 21, Selected True,
# Column: 23, Selected True,
# Column: 31, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 7, 13, 21, 23, 31, 38, 40, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [31]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117, 7, 13, 23, 31]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898, 975.41, 2160.534, 973.579, 1878.725]
#
# 24
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 7, Selected True,
# Column: 13, Selected True,
# Column: 21, Selected True,
# Column: 23, Selected True,
# Column: 31, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 59, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 7, 13, 21, 23, 31, 38, 40, 59, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [59]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117, 7, 13, 23, 31, 59]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898, 975.41, 2160.534, 973.579, 1878.725, 930.262]
#
# 25
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 7, Selected True,
# Column: 13, Selected True,
# Column: 21, Selected True,
# Column: 23, Selected True,
# Column: 31, Selected True,
# Column: 35, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 59, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 7, 13, 21, 23, 31, 35, 38, 40, 59, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [35]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117, 7, 13, 23, 31, 59, 35]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898, 975.41, 2160.534, 973.579, 1878.725, 930.262, 1508.226]
#
# 26
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 7, Selected True,
# Column: 9, Selected True,
# Column: 13, Selected True,
# Column: 21, Selected True,
# Column: 23, Selected True,
# Column: 31, Selected True,
# Column: 35, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 59, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 3, 5, 7, 9, 13, 21, 23, 31, 35, 38, 40, 59, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [9]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117, 7, 13, 23, 31, 59, 35, 9]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898, 975.41, 2160.534, 973.579, 1878.725, 930.262, 1508.226, 2002.039]
#
# 27
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 2, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 7, Selected True,
# Column: 9, Selected True,
# Column: 13, Selected True,
# Column: 21, Selected True,
# Column: 23, Selected True,
# Column: 31, Selected True,
# Column: 35, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 59, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 2, 3, 5, 7, 9, 13, 21, 23, 31, 35, 38, 40, 59, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [2]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117, 7, 13, 23, 31, 59, 35, 9, 2]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898, 975.41, 2160.534, 973.579, 1878.725, 930.262, 1508.226, 2002.039, 1229.322]
#
# 28
# Column: 0, Selected True,
# Column: 1, Selected True,
# Column: 2, Selected True,
# Column: 3, Selected True,
# Column: 5, Selected True,
# Column: 7, Selected True,
# Column: 9, Selected True,
# Column: 13, Selected True,
# Column: 21, Selected True,
# Column: 23, Selected True,
# Column: 31, Selected True,
# Column: 35, Selected True,
# Column: 38, Selected True,
# Column: 40, Selected True,
# Column: 41, Selected True,
# Column: 59, Selected True,
# Column: 61, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 99, Selected True,
# Column: 101, Selected True,
# Column: 117, Selected True,
# Column: 136, Selected True,
# Column: 148, Selected True,
# Column: 177, Selected True,
# Column: 201, Selected True,
# Column: 232, Selected True,
# Column: 371, Selected True,
# [0, 1, 2, 3, 5, 7, 9, 13, 21, 23, 31, 35, 38, 40, 41, 59, 61, 85, 86, 99, 101, 117, 136, 148, 177, 201, 232, 371]
# [41]
# [371, 38, 99, 201, 177, 1, 40, 148, 232, 86, 3, 21, 0, 136, 61, 5, 85, 101, 117, 7, 13, 23, 31, 59, 35, 9, 2, 41]
# [1394.643, 2130.354, 883.353, 1365.266, 1886.929, 883.052, 1174.203, 1492.597, 1465.597, 1426.095, 989.18, 1499.503, 1018.719, 1331.608, 1837.449, 2450.511, 1379.798, 943.465, 1921.898, 975.41, 2160.534, 973.579, 1878.725, 930.262, 1508.226, 2002.039, 1229.322, 1523.291]
#
# 29

# %% [markdown]
# ---

# %% [markdown]
# ### LR

# %%
lr = LogisticRegression()

# %%
solvers = ['newton-cg', 'liblinear']
penalty = ['l2']
c_values = [1000, 100, 10, 1.0, 0.1, 0.01, 0.001]
lr_par = dict(solver=solvers,penalty=penalty,C=c_values)

# %%
models = [[lr, 'lr', 14]]
par = [lr_par]

# %%
from source.ml_acc import get_accuracy_ml

# %%
num_ml_tools = len(par)
ml_dicts = {}

for m, par in zip(models, par):
    key0 = str(m[1])
    ml_dicts[key0] = {}
    for f in selected:
        print(cols_ordered[f])

        xtr =  Xtrain[cols_ordered].iloc[:, f]
        xte =  Xtest[cols_ordered].iloc[:, f]
        print(xtr)
        results = get_accuracy_ml (m[0], m[2], par, np.array(xtr), np.array(Ytrain), np.array(xte), np.array(Ytest)) # to get the accuracies for the ml model

        key = str(m[1])+","+str(len(f))
        ml_dicts[key0][key] = {}

        ml_dicts[key0][key]['tot_acc'] = results[0]
        ml_dicts[key0][key]['jack_train'] = results[1]
        ml_dicts[key0][key]['jack_test'] = results[2]

# %% [markdown]
# ---

# %%
import json

# %%
with open('ml_gd_fs9.txt', 'w') as file:
     file.write(json.dumps(ml_dicts)) # use `json.loads` to do the reverse

# %%
import json
with open('ml_gd_fs9.txt') as f:
    data = f.read()
    
ml_dicts = json.loads(data)

with open('base_gd.txt') as f:
    data = f.read()
    
baseDict = json.loads(data)
baseDict['lr'].keys()
# Out:
# dict_keys(['lr, all'])

# %%
print(baseDict['lr'].keys()    )
print(ml_dicts['lr'].keys()    )
# Out:
# dict_keys(['lr, all'])
# dict_keys(['lr,1', 'lr,2', 'lr,3', 'lr,4', 'lr,5', 'lr,6', 'lr,7', 'lr,8', 'lr,9', 'lr,10', 'lr,11', 'lr,12', 'lr,13', 'lr,14', 'lr,15', 'lr,16', 'lr,17', 'lr,18', 'lr,19', 'lr,20', 'lr,21', 'lr,22', 'lr,23', 'lr,24', 'lr,25', 'lr,26', 'lr,27', 'lr,28', 'lr,29', 'lr,30', 'lr,31', 'lr,32', 'lr,33', 'lr,34', 'lr,35', 'lr,36', 'lr,37', 'lr,38', 'lr,39', 'lr,40', 'lr,41', 'lr,42', 'lr,43', 'lr,44', 'lr,45', 'lr,46', 'lr,47', 'lr,48', 'lr,49', 'lr,50'])

# %%
from source.calculate_jack import jack_SD # importing the baseline code from source.basline file

# %%
arr_all = []
for m, d in zip (models, ml_dicts.keys()):
    acc_arr = [] 
    sd_arr = [] 

    # print(ml_dicts[d])
    for key in ml_dicts[d].keys():
        acc_arr.append(ml_dicts[d][key][ 'tot_acc' ]) # append total accuracy to an array
        sd_train = jack_SD(np.zeros( len(ml_dicts[d][key][ 'jack_train' ]) ), ml_dicts[d][key][ 'jack_train' ])[0]
        sd_test = jack_SD(np.zeros( len(ml_dicts[d][key][ 'jack_test' ]) ), ml_dicts[d][key][ 'jack_test' ])[0]
        sd = np.sqrt( np.array((sd_train**2)) + np.array((sd_test**2)))
        sd_arr.append(sd) # append sd_arr to an array
    arr_all.append([ list(ml_dicts[d].keys()), acc_arr, sd_arr])

# %%
colors = ['blue', 'purple', 'green', 'orange', 'red', 'brown']
plt.figure(figsize=(15, 7))
plt.title( "Precision  for different features with the SD", fontweight ='bold', fontsize =12)
plt.xlabel("Features", fontweight ='bold', fontsize =12)
plt.ylabel("Precision", fontweight ='bold', fontsize =12)

count = 0
n = len(colors)-1

space = []
tickFeat = []

for result, model, color in zip(arr_all, models, colors):
    a = np.linspace(n*count, n*(1+count)-2,50)
    print(a)
    space.extend(a)
    tickFeat.extend(result[0])
    plt.errorbar( a, result[1], result[2], fmt='o', label =model[1], color = color)
    count += 1

plt.xticks(space, tickFeat, rotation = 'vertical',  fontsize =12)
plt.ylim(.2, 1)
plt.legend()

plt.show()
# Out:
# [0.         0.06122449 0.12244898 0.18367347 0.24489796 0.30612245
#  0.36734694 0.42857143 0.48979592 0.55102041 0.6122449  0.67346939
#  0.73469388 0.79591837 0.85714286 0.91836735 0.97959184 1.04081633
#  1.10204082 1.16326531 1.2244898  1.28571429 1.34693878 1.40816327
#  1.46938776 1.53061224 1.59183673 1.65306122 1.71428571 1.7755102
#  1.83673469 1.89795918 1.95918367 2.02040816 2.08163265 2.14285714
#  2.20408163 2.26530612 2.32653061 2.3877551  2.44897959 2.51020408
#  2.57142857 2.63265306 2.69387755 2.75510204 2.81632653 2.87755102
#  2.93877551 3.        ]

# %%
arr_diff_all = []

for m, m_key in zip (models, ml_dicts.keys()):
    acc_diff_arr = [] 
    sd_diff_arr = [] 
    for f_key in ml_dicts[m_key].keys():
        value = f_key.split(',')
        acc_diff_arr.append( ml_dicts[m_key][f_key][ 'tot_acc' ] - baseDict['lr']['lr, all'][ 'tot_acc' ]  )

        sd_train = jack_SD( baseDict['lr']['lr, all'][ 'jack_train' ], ml_dicts[m_key][f_key]['jack_train'] )[0]
        sd_test = jack_SD(  baseDict['lr']['lr, all'][ 'jack_test' ],  ml_dicts[m_key][f_key]['jack_test']   )[0]

        sd = np.sqrt( np.array((sd_train**2)) + np.array((sd_test**2)))
        sd_diff_arr.append(sd) # append sd_arr to an array
    arr_diff_all.append([ list(ml_dicts[m_key].keys()), acc_diff_arr, sd_diff_arr])

# %%
colors = ['blue', 'purple', 'green', 'orange', 'red', 'brown']
plt.figure(figsize=(15, 7))
plt.title( "Precision  differences for ML methods versus LR_all for feature setsD", fontweight ='bold', fontsize =12)
plt.xlabel("Features", fontweight ='bold', fontsize =12)
plt.ylabel("Precision  difference", fontweight ='bold', fontsize =12)

count = 0
n = len(colors)-0.5
space = []
tickFeat = []

for result, model, color in zip(arr_diff_all, models, colors):
    a = np.linspace(n*count, n*(1+count)-2,50)
    space.extend(a)
    tickFeat.extend(result[0])
    plt.errorbar( a, result[1], result[2], fmt='o', label =model[1], color = color)
    count += 1
    
plt.plot(np.array(space), np.zeros(50*1), color = 'Black')        
plt.xticks(space, tickFeat, rotation = 'vertical',  fontsize =12)
plt.ylim(-.5, 1)
plt.legend()

plt.show()

# %%
print(1)
