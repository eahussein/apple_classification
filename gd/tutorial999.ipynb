# %% [markdown]
# # Tutorial 999: addition on the best 400 features, backwords

# %% [markdown]
# ---

# %% [markdown]
# ### Introduction

# %% [markdown]
# Hello, this notebook will show how to use sequential adding to perform further feature selection, as we found that most features are very highly correlated, therfore we would need to remove those using the tool that we mentioned above.

# %% [markdown]
# first, let us call the data

# %%
# %store -r df_input_GD
# %store -r y_GD
# %store -r df_GD

# %%
y_GD = y_GD.map({'S': 1, 'B': 0})

# %% [markdown]
# ---

# %% [markdown]
# calling some packages

# %%
# Python packages 
import pandas as pd # for importing data into data frame format
import seaborn as sns # For drawing useful graphs, such as bar graphs
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# <b><i> Data splitting </i></b>

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, Ytrain, Ytest = train_test_split( df_input_GD, y_GD, test_size = 0.3, random_state=3, stratify=y_GD) # train and valid sets

# %%
print(Xtrain.shape)
print(Xtest.shape)
# Out:
# (382, 2074)
# (165, 2074)

# %% [markdown]
# ---

# %% [markdown]
# <b><i> get the best N features </i></b>

# %%
# %store -r featImp_GD

# %%
arrimp = np.array(featImp_GD).mean(0)
sorted_idx = arrimp.argsort()
print(sorted_idx[-10:])
# Out:
# [ 15 205 144 153  71 180 157  60  43  86]

# %%
cols_ordered = df_input_GD.columns[sorted_idx][-100:]
cols_ordered
# Out:
# Index([ 843.409,  895.867, 1275.906, 1158.981, 1859.857,  880.652, 1838.752,
#         886.373, 1393.144,  865.656, 1534.107,  894.014, 1997.412,  878.861,
#         847.545,  940.726,  984.672,  1180.62, 1404.464,  885.163, 1470.585,
#        1710.185, 1085.695,   954.58, 1296.969, 1977.605,  898.974,  865.079,
#          842.04,  890.024, 1170.492, 2490.529, 2294.372,   890.33, 1250.671,
#        1173.672,  2387.33,   1533.2,  854.247, 1854.535, 2483.372,  862.202,
#        1328.197,   932.94, 1254.301,  863.638, 1010.382,  1548.77,   881.55,
#        1398.404,  894.322, 2052.764, 1181.696, 1881.452,  850.325, 1327.517,
#         931.934,  878.563, 2500.136,  853.404,  917.424,  879.756,  909.699,
#        1944.967, 1399.914, 1395.393, 1317.399, 1252.483,   869.43,  839.314,
#        1242.877, 1394.643, 1301.526,  874.415,  967.042, 1535.015, 1402.944,
#         881.851,  875.892, 1311.401,  900.535, 1936.251,  871.769, 2443.582,
#         901.162,  891.555,  863.063, 2434.404,  842.587,  838.229,  837.687,
#         892.475,  874.121,  876.781,  853.123,   884.86,  877.969,  850.046,
#         845.334,  857.355],
#       dtype='object')

# %% [markdown]
# ---

# %%
Xtrain[cols_ordered]
# Out:
#      843.409   895.867   1275.906  1158.981  1859.857  880.652   1838.752  \
# 228 -1.039885 -1.037273 -1.140833 -1.152677 -0.919110 -1.033298 -0.995799
# 474  1.217447  1.249408  1.339182  1.330748  1.246885  1.230618  1.287938
# 273  1.136137  1.144752  1.143996  1.151181  1.012849  1.143445  1.031710
# 285  1.022982  0.996900  0.790374  0.784084  0.441619  1.010167  0.484189
# 20  -0.796105 -0.784331 -0.669144 -0.618360  0.001774 -0.788693 -0.086524
# ..        ...       ...       ...       ...       ...       ...       ...
# 391  1.247485  1.259455  1.284808  1.291973  1.396446  1.255319  1.393546
# 71  -0.975608 -0.958602 -0.993775 -0.966866 -0.368766 -0.964191 -0.503396
# 287  1.089283  1.104891  1.186758  1.192422  0.601280  1.098719  0.710221
# 66  -1.284476 -1.283627 -1.464046 -1.484982 -1.691566 -1.280984 -1.684046
# 85  -1.020832 -1.025489 -1.072961 -1.029932 -1.057346 -1.026087 -1.070760
#
#      886.373   1393.144  865.656   ...  837.687   892.475   874.121   \
# 228 -1.033625 -0.949629 -1.030900  ... -1.040947 -1.035275 -1.030146
# 474  1.238834  1.236445  1.217417  ...  1.210396  1.244742  1.230255
# 273  1.142008  1.085233  1.142426  ...  1.127660  1.141946  1.144145
# 285  1.003955  0.490740  1.019905  ...  1.017840  1.000981  1.012044
# 20  -0.787463 -0.010336 -0.796340  ... -0.797608 -0.788356 -0.792682
# ..        ...       ...       ...  ...       ...       ...       ...
# 391  1.262182  1.341043  1.249928  ...  1.240678  1.262327  1.258593
# 71  -0.962801 -0.435917 -0.970713  ... -0.981073 -0.963380 -0.965990
# 287  1.098134  0.694964  1.095827  ...  1.088064  1.103508  1.098137
# 66  -1.279037 -1.697375 -1.280753  ... -1.292153 -1.282100 -1.279279
# 85  -1.023496 -1.049148 -1.029082  ... -1.024621 -1.025982 -1.027971
#
#      876.781   853.123   884.860   877.969   850.046   845.334   857.355
# 228 -1.033481 -1.032521 -1.034466 -1.029368 -1.031805 -1.039755 -1.031936
# 474  1.231594  1.220015  1.233132  1.230056  1.216652  1.215678  1.224416
# 273  1.144791  1.137959  1.144632  1.144275  1.139449  1.133384  1.144581
# 285  1.010621  1.020728  1.009804  1.008720  1.020247  1.022598  1.018547
# 20  -0.789674 -0.799611 -0.786075 -0.790533 -0.802299 -0.794386 -0.800824
# ..        ...       ...       ...       ...       ...       ...       ...
# 391  1.259826  1.246070  1.264388  1.259422  1.246331  1.244710  1.247542
# 71  -0.963353 -0.978024 -0.959486 -0.964945 -0.978210 -0.975422 -0.977062
# 287  1.097991  1.090781  1.102332  1.098439  1.096154  1.096031  1.091843
# 66  -1.279909 -1.284921 -1.277541 -1.281256 -1.285772 -1.282308 -1.285889
# 85  -1.025618 -1.028104 -1.024180 -1.028601 -1.025806 -1.022977 -1.030241
#
# [382 rows x 100 columns]

# %% [markdown]
# ### SFS

# %%
# explore the number of selected features for RFE
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.pipeline import Pipeline
from matplotlib import pyplot
from sklearn.linear_model import LogisticRegression

# %%
# https://machinelearningmastery.com/rfe-feature-selection-in-python/
selected = []
imp_ind = []
imp_freq = []

for i in range(1, 51, 1):
    print(i)
    sfs = SequentialFeatureSelector(estimator=LogisticRegression(solver = 'newton-cg'), n_features_to_select=i, direction = 'backward')
    # fit sfs
    sfs.fit(Xtrain[cols_ordered].values, Ytrain)
    # summarize all features
    selected_feat = []
    for i in range(Xtrain[cols_ordered].shape[1]):
        if sfs.support_[i] == True:
            selected_feat.append(i)
            print('Column: %d, Selected %s,' % (i, sfs.support_[i]))
        
    # print()
    selected.append(selected_feat)
    
    result = list(set(imp_ind) ^ set(selected[-1]))
    imp_freq.extend(Xtrain[cols_ordered].columns[result])    
    imp_ind.extend(result)    
    
    print(selected[-1])
    print(result)
    print(imp_ind)
    print(imp_freq)
    print()
# Out:
# 1
# Column: 55, Selected True,
# [55]
# [55]
# [55]
# [1327.517]
#
# 2
# Column: 55, Selected True,
# Column: 85, Selected True,
# [55, 85]
# [85]
# [55, 85]
# [1327.517, 891.555]
#
# 3
# Column: 20, Selected True,
# Column: 55, Selected True,
# Column: 85, Selected True,
# [20, 55, 85]
# [20]
# [55, 85, 20]
# [1327.517, 891.555, 1470.585]
#
# 4
# Column: 20, Selected True,
# Column: 55, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# [20, 55, 84, 85]
# [84]
# [55, 85, 20, 84]
# [1327.517, 891.555, 1470.585, 901.162]
#
# 5
# Column: 20, Selected True,
# Column: 55, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# [20, 55, 84, 85, 95]
# [95]
# [55, 85, 20, 84, 95]
# [1327.517, 891.555, 1470.585, 901.162, 884.86]
#
# 6
# Column: 20, Selected True,
# Column: 55, Selected True,
# Column: 66, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# [20, 55, 66, 84, 85, 95]
# [66]
# [55, 85, 20, 84, 95, 66]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399]
#
# 7
# Column: 20, Selected True,
# Column: 55, Selected True,
# Column: 66, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 55, 66, 84, 85, 95, 98]
# [98]
# [55, 85, 20, 84, 95, 66, 98]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334]
#
# 8
# Column: 20, Selected True,
# Column: 55, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 55, 66, 70, 84, 85, 95, 98]
# [70]
# [55, 85, 20, 84, 95, 66, 98, 70]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877]
#
# 9
# Column: 20, Selected True,
# Column: 55, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 80, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 55, 66, 70, 80, 84, 85, 95, 98]
# [80]
# [55, 85, 20, 84, 95, 66, 98, 70, 80]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535]
#
# 10
# Column: 20, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 80, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 55, 62, 66, 70, 80, 84, 85, 95, 98]
# [62]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699]
#
# 11
# Column: 20, Selected True,
# Column: 42, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 80, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 42, 55, 62, 66, 70, 80, 84, 85, 95, 98]
# [42]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197]
#
# 12
# Column: 20, Selected True,
# Column: 42, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 80, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 42, 53, 55, 62, 66, 70, 80, 84, 85, 95, 98]
# [53]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452]
#
# 13
# Column: 20, Selected True,
# Column: 42, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 80, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 42, 53, 55, 62, 66, 70, 80, 83, 84, 85, 95, 98]
# [83]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582]
#
# 14
# Column: 20, Selected True,
# Column: 42, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 42, 53, 55, 62, 66, 70, 79, 80, 83, 84, 85, 95, 98]
# [79]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401]
#
# 15
# Column: 20, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 40, 42, 53, 55, 62, 66, 70, 79, 80, 83, 84, 85, 95, 98]
# [40]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372]
#
# 16
# Column: 20, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 40, 42, 53, 55, 62, 66, 70, 79, 80, 82, 83, 84, 85, 95, 98]
# [82]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769]
#
# 17
# Column: 20, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 30, 40, 42, 53, 55, 62, 66, 70, 79, 80, 82, 83, 84, 85, 95, 98]
# [30]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492]
#
# 18
# Column: 20, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [20, 30, 40, 42, 51, 53, 55, 62, 66, 70, 79, 80, 82, 83, 84, 85, 95, 98]
# [51]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764]
#
# 19
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [3, 20, 30, 40, 42, 51, 53, 55, 62, 66, 70, 79, 80, 82, 83, 84, 85, 95, 98]
# [3]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981]
#
# 20
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [3, 20, 30, 40, 42, 51, 53, 55, 62, 66, 70, 72, 79, 80, 82, 83, 84, 85, 95, 98]
# [72]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526]
#
# 21
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [3, 20, 30, 40, 42, 51, 53, 55, 62, 66, 70, 72, 75, 79, 80, 82, 83, 84, 85, 95, 98]
# [75]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015]
#
# 22
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [3, 20, 24, 30, 40, 42, 51, 53, 55, 62, 66, 70, 72, 75, 79, 80, 82, 83, 84, 85, 95, 98]
# [24]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969]
#
# 23
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [3, 20, 24, 30, 40, 42, 51, 53, 55, 60, 62, 66, 70, 72, 75, 79, 80, 82, 83, 84, 85, 95, 98]
# [60]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424]
#
# 24
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 93, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [3, 20, 24, 30, 40, 42, 51, 53, 55, 60, 62, 66, 70, 72, 75, 79, 80, 82, 83, 84, 85, 93, 95, 98]
# [93]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781]
#
# 25
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [3, 20, 24, 30, 40, 42, 51, 53, 55, 60, 62, 66, 70, 72, 75, 79, 80, 82, 83, 84, 85, 92, 93, 95, 98]
# [92]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121]
#
# 26
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 95, Selected True,
# Column: 98, Selected True,
# [3, 20, 24, 30, 40, 42, 51, 53, 55, 56, 60, 62, 66, 70, 72, 75, 79, 80, 82, 83, 84, 85, 92, 93, 95, 98]
# [56]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934]
#
# 27
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 95, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# [3, 20, 24, 30, 40, 42, 51, 53, 55, 56, 60, 62, 66, 70, 72, 75, 79, 80, 82, 83, 84, 85, 92, 93, 95, 97, 98]
# [97]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046]
#
# 28
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 95, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# [3, 20, 24, 30, 40, 42, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 82, 83, 84, 85, 92, 93, 95, 97, 98]
# [67]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483]
#
# 29
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 95, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# [3, 20, 24, 30, 40, 42, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 82, 83, 84, 85, 92, 93, 95, 97, 98]
# [50]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322]
#
# 30
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 95, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 40, 42, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 82, 83, 84, 85, 92, 93, 95, 97, 98, 99]
# [99]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355]
#
# 31
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 40, 42, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 82, 83, 84, 85, 92, 93, 94, 95, 97, 98, 99]
# [94]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123]
#
# 32
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 40, 42, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 82, 83, 84, 85, 86, 92, 93, 94, 95, 97, 98, 99]
# [86]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063]
#
# 33
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 37, 40, 42, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 82, 83, 84, 85, 86, 92, 93, 94, 95, 97, 98, 99]
# [37]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2]
#
# 34
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 37, 40, 42, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 82, 83, 84, 85, 86, 91, 92, 93, 94, 95, 97, 98, 99]
# [91]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475]
#
# 35
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 37, 40, 42, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 82, 83, 84, 85, 86, 90, 91, 92, 93, 94, 95, 97, 98, 99]
# [90]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687]
#
# 36
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 96, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 37, 40, 42, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 82, 83, 84, 85, 86, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# [96]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90, 96]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687, 877.969]
#
# 37
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 81, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 96, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 37, 40, 42, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 81, 82, 83, 84, 85, 86, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# [81]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90, 96, 81]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687, 877.969, 1936.251]
#
# 38
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 44, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 81, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 96, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 37, 40, 42, 44, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 81, 82, 83, 84, 85, 86, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# [44]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90, 96, 81, 44]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687, 877.969, 1936.251, 1254.301]
#
# 39
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 34, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 44, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 81, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 96, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 34, 37, 40, 42, 44, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 81, 82, 83, 84, 85, 86, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# [34]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90, 96, 81, 44, 34]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687, 877.969, 1936.251, 1254.301, 1250.671]
#
# 40
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 34, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 44, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 81, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 89, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 96, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 34, 37, 40, 42, 44, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 79, 80, 81, 82, 83, 84, 85, 86, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# [89]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90, 96, 81, 44, 34, 89]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687, 877.969, 1936.251, 1254.301, 1250.671, 838.229]
#
# 41
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 34, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 44, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 78, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 81, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 89, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 96, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 34, 37, 40, 42, 44, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 78, 79, 80, 81, 82, 83, 84, 85, 86, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# [78]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90, 96, 81, 44, 34, 89, 78]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687, 877.969, 1936.251, 1254.301, 1250.671, 838.229, 875.892]
#
# 42
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 34, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 44, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 77, Selected True,
# Column: 78, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 81, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 89, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 96, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 34, 37, 40, 42, 44, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# [77]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90, 96, 81, 44, 34, 89, 78, 77]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687, 877.969, 1936.251, 1254.301, 1250.671, 838.229, 875.892, 881.851]
#
# 43
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 33, Selected True,
# Column: 34, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 44, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 77, Selected True,
# Column: 78, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 81, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 89, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 96, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 33, 34, 37, 40, 42, 44, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# [33]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90, 96, 81, 44, 34, 89, 78, 77, 33]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687, 877.969, 1936.251, 1254.301, 1250.671, 838.229, 875.892, 881.851, 890.33]
#
# 44
# Column: 3, Selected True,
# Column: 20, Selected True,
# Column: 24, Selected True,
# Column: 30, Selected True,
# Column: 33, Selected True,
# Column: 34, Selected True,
# Column: 37, Selected True,
# Column: 40, Selected True,
# Column: 42, Selected True,
# Column: 44, Selected True,
# Column: 50, Selected True,
# Column: 51, Selected True,
# Column: 53, Selected True,
# Column: 55, Selected True,
# Column: 56, Selected True,
# Column: 60, Selected True,
# Column: 62, Selected True,
# Column: 66, Selected True,
# Column: 67, Selected True,
# Column: 70, Selected True,
# Column: 72, Selected True,
# Column: 75, Selected True,
# Column: 76, Selected True,
# Column: 77, Selected True,
# Column: 78, Selected True,
# Column: 79, Selected True,
# Column: 80, Selected True,
# Column: 81, Selected True,
# Column: 82, Selected True,
# Column: 83, Selected True,
# Column: 84, Selected True,
# Column: 85, Selected True,
# Column: 86, Selected True,
# Column: 89, Selected True,
# Column: 90, Selected True,
# Column: 91, Selected True,
# Column: 92, Selected True,
# Column: 93, Selected True,
# Column: 94, Selected True,
# Column: 95, Selected True,
# Column: 96, Selected True,
# Column: 97, Selected True,
# Column: 98, Selected True,
# Column: 99, Selected True,
# [3, 20, 24, 30, 33, 34, 37, 40, 42, 44, 50, 51, 53, 55, 56, 60, 62, 66, 67, 70, 72, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# [76]
# [55, 85, 20, 84, 95, 66, 98, 70, 80, 62, 42, 53, 83, 79, 40, 82, 30, 51, 3, 72, 75, 24, 60, 93, 92, 56, 97, 67, 50, 99, 94, 86, 37, 91, 90, 96, 81, 44, 34, 89, 78, 77, 33, 76]
# [1327.517, 891.555, 1470.585, 901.162, 884.86, 1317.399, 845.334, 1242.877, 900.535, 909.699, 1328.197, 1881.452, 2443.582, 1311.401, 2483.372, 871.769, 1170.492, 2052.764, 1158.981, 1301.526, 1535.015, 1296.969, 917.424, 876.781, 874.121, 931.934, 850.046, 1252.483, 894.322, 857.355, 853.123, 863.063, 1533.2, 892.475, 837.687, 877.969, 1936.251, 1254.301, 1250.671, 838.229, 875.892, 881.851, 890.33, 1402.944]
#
# 45
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 6>()
#       8 sfs = SequentialFeatureSelector(estimator=LogisticRegression(solver = 'newton-cg'), n_features_to_select=i, direction = 'backward')
#       9 # fit sfs
# ---> 10 sfs.fit(Xtrain[cols_ordered].values, Ytrain)
#      11 # summarize all features
#      12 selected_feat = []
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/feature_selection/_sequential.py:209, in SequentialFeatureSelector.fit(self, X, y)
#     203 n_iterations = (
#     204     self.n_features_to_select_
#     205     if self.direction == "forward"
#     206     else n_features - self.n_features_to_select_
#     207 )
#     208 for _ in range(n_iterations):
# --> 209     new_feature_idx = self._get_best_new_feature(
#     210         cloned_estimator, X, y, current_mask
#     211     )
#     212     current_mask[new_feature_idx] = True
#     214 if self.direction == "backward":
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/feature_selection/_sequential.py:232, in SequentialFeatureSelector._get_best_new_feature(self, estimator, X, y, current_mask)
#     230         candidate_mask = ~candidate_mask
#     231     X_new = X[:, candidate_mask]
# --> 232     scores[feature_idx] = cross_val_score(
#     233         estimator,
#     234         X_new,
#     235         y,
#     236         cv=self.cv,
#     237         scoring=self.scoring,
#     238         n_jobs=self.n_jobs,
#     239     ).mean()
#     240 return max(scores, key=lambda feature_idx: scores[feature_idx])
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# --> 509 cv_results = cross_validate(
#     510     estimator=estimator,
#     511     X=X,
#     512     y=y,
#     513     groups=groups,
#     514     scoring={"score": scorer},
#     515     cv=cv,
#     516     n_jobs=n_jobs,
#     517     verbose=verbose,
#     518     fit_params=fit_params,
#     519     pre_dispatch=pre_dispatch,
#     520     error_score=error_score,
#     521 )
#     522 return cv_results["test_score"]
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:267, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267 results = parallel(
#     268     delayed(_fit_and_score)(
#     269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1589, in LogisticRegression.fit(self, X, y, sample_weight)
#    1587 else:
#    1588     prefer = "processes"
# -> 1589 fold_coefs_ = Parallel(
#    1590     n_jobs=self.n_jobs,
#    1591     verbose=self.verbose,
#    1592     **_joblib_parallel_args(prefer=prefer),
#    1593 )(
#    1594     path_func(
#    1595         X,
#    1596         y,
#    1597         pos_class=class_,
#    1598         Cs=[C_],
#    1599         l1_ratio=self.l1_ratio,
#    1600         fit_intercept=self.fit_intercept,
#    1601         tol=self.tol,
#    1602         verbose=self.verbose,
#    1603         solver=solver,
#    1604         multi_class=multi_class,
#    1605         max_iter=self.max_iter,
#    1606         class_weight=self.class_weight,
#    1607         check_input=False,
#    1608         random_state=self.random_state,
#    1609         coef=warm_start_coef_,
#    1610         penalty=penalty,
#    1611         max_squared_sum=max_squared_sum,
#    1612         sample_weight=sample_weight,
#    1613     )
#    1614     for class_, warm_start_coef_ in zip(classes_, warm_start_coef)
#    1615 )
#    1617 fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#    1618 self.n_iter_ = np.asarray(n_iter_, dtype=np.int32)[:, 0]
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:823, in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     821 elif solver == "newton-cg":
#     822     args = (X, target, 1.0 / C, sample_weight)
# --> 823     w0, n_iter_i = _newton_cg(
#     824         hess, func, grad, w0, args=args, maxiter=max_iter, tol=tol
#     825     )
#     826 elif solver == "liblinear":
#     827     coef_, intercept_, n_iter_i, = _fit_liblinear(
#     828         X,
#     829         target,
#    (...)
#     840         sample_weight=sample_weight,
#     841     )
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/utils/optimize.py:199, in _newton_cg(grad_hess, func, grad, x0, args, tol, maxiter, maxinner, line_search, warn)
#     197 if line_search:
#     198     try:
# --> 199         alphak, fc, gc, old_fval, old_old_fval, gfkp1 = _line_search_wolfe12(
#     200             func, grad, xk, xsupi, fgrad, old_fval, old_old_fval, args=args
#     201         )
#     202     except _LineSearchError:
#     203         warnings.warn("Line Search failed")
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/utils/optimize.py:39, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#      27 def _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs):
#      28     """
#      29     Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#      30     suitable step length is not found, and raise an exception if a
#    (...)
#      37
#      38     """
# ---> 39     ret = line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#      41     if ret[0] is None:
#      42         # line search failed: try different one.
#      43         ret = line_search_wolfe2(
#      44             f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs
#      45         )
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/scipy/optimize/_linesearch.py:84, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      80     return np.dot(gval[0], pk)
#      82 derphi0 = np.dot(gfk, pk)
# ---> 84 stp, fval, old_fval = scalar_search_wolfe1(
#      85         phi, derphi, old_fval, old_old_fval, derphi0,
#      86         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      88 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/scipy/optimize/_linesearch.py:161, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     159     alpha1 = stp
#     160     phi1 = phi(stp)
# --> 161     derphi1 = derphi(stp)
#     162 else:
#     163     break
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/scipy/optimize/_linesearch.py:78, in line_search_wolfe1.<locals>.derphi(s)
#      77 def derphi(s):
# ---> 78     gval[0] = fprime(xk + s*pk, *args)
#      79     gc[0] += 1
#      80     return np.dot(gval[0], pk)
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:794, in _logistic_regression_path.<locals>.grad(x, *args)
#     793 def grad(x, *args):
# --> 794     return _logistic_loss_and_grad(x, *args)[1]
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:127, in _logistic_loss_and_grad(w, X, y, alpha, sample_weight)
#     124 z = expit(yz)
#     125 z0 = sample_weight * (z - 1) * y
# --> 127 grad[:n_features] = safe_sparse_dot(X.T, z0) + alpha * w
#     129 # Case where we fit the intercept.
#     130 if grad.shape[0] > n_features:
#
# File ~/source/apple_classification/appleVer/lib/python3.8/site-packages/sklearn/utils/extmath.py:153, in safe_sparse_dot(a, b, dense_output)
#     151         ret = np.dot(a, b)
#     152 else:
# --> 153     ret = a @ b
#     155 if (
#     156     sparse.issparse(a)
#     157     and sparse.issparse(b)
#     158     and dense_output
#     159     and hasattr(ret, "toarray")
#     160 ):
#     161     return ret.toarray()
#
# KeyboardInterrupt:

# %% [markdown]
# ---

# %% [markdown]
# ### LR

# %%
lr = LogisticRegression()

# %%
solvers = ['newton-cg', 'liblinear']
penalty = ['l2']
c_values = [1000, 100, 10, 1.0, 0.1, 0.01, 0.001]
lr_par = dict(solver=solvers,penalty=penalty,C=c_values)

# %%
models = [[lr, 'lr', 14]]
par = [lr_par]

# %%
from source.ml_acc import get_accuracy_ml

# %%
num_ml_tools = len(par)
ml_dicts = {}

for m, par in zip(models, par):
    key0 = str(m[1])
    ml_dicts[key0] = {}
    for f in selected:
        print(cols_ordered[f])

        xtr =  Xtrain[cols_ordered].iloc[:, f]
        xte =  Xtest[cols_ordered].iloc[:, f]
        print(xtr)
        results = get_accuracy_ml (m[0], m[2], par, np.array(xtr), np.array(Ytrain), np.array(xte), np.array(Ytest)) # to get the accuracies for the ml model

        key = str(m[1])+","+str(len(f))
        ml_dicts[key0][key] = {}

        ml_dicts[key0][key]['tot_acc'] = results[0]
        ml_dicts[key0][key]['jack_train'] = results[1]
        ml_dicts[key0][key]['jack_test'] = results[2]
# Out:
# Index([1327.517], dtype='object')
#      1327.517
# 228 -1.145751
# 474  1.335652
# 273  1.134744
# 285  0.710256
# 20  -0.533725
# ..        ...
# 391  1.298965
# 71  -0.939193
# 287  1.153168
# 66  -1.550440
# 85  -1.057401
#
# [382 rows x 1 columns]
# Index([1327.517, 891.555], dtype='object')
#      1327.517   891.555
# 228 -1.145751 -1.036672
# 474  1.335652  1.238027
# 273  1.134744  1.146828
# 285  0.710256  1.000195
# 20  -0.533725 -0.785242
# ..        ...       ...
# 391  1.298965  1.266988
# 71  -0.939193 -0.960666
# 287  1.153168  1.100592
# 66  -1.550440 -1.279788
# 85  -1.057401 -1.023923
#
# [382 rows x 2 columns]
# Index([1470.585, 1327.517, 891.555], dtype='object')
#      1470.585  1327.517   891.555
# 228 -0.781553 -1.145751 -1.036672
# 474  1.179396  1.335652  1.238027
# 273  1.042295  1.134744  1.146828
# 285  0.405851  0.710256  1.000195
# 20  -0.006786 -0.533725 -0.785242
# ..        ...       ...       ...
# 391  1.368076  1.298965  1.266988
# 71  -0.191294 -0.939193 -0.960666
# 287  0.354587  1.153168  1.100592
# 66  -1.715595 -1.550440 -1.279788
# 85  -1.152630 -1.057401 -1.023923
#
# [382 rows x 3 columns]
# Index([1470.585, 1327.517, 901.162, 891.555], dtype='object')
#      1470.585  1327.517   901.162   891.555
# 228 -0.781553 -1.145751 -1.039174 -1.036672
# 474  1.179396  1.335652  1.246576  1.238027
# 273  1.042295  1.134744  1.142621  1.146828
# 285  0.405851  0.710256  1.000185  1.000195
# 20  -0.006786 -0.533725 -0.784054 -0.785242
# ..        ...       ...       ...       ...
# 391  1.368076  1.298965  1.265312  1.266988
# 71  -0.191294 -0.939193 -0.960707 -0.960666
# 287  0.354587  1.153168  1.102646  1.100592
# 66  -1.715595 -1.550440 -1.284899 -1.279788
# 85  -1.152630 -1.057401 -1.027692 -1.023923
#
# [382 rows x 4 columns]
# Index([1470.585, 1327.517, 901.162, 891.555, 884.86], dtype='object')
# ..        ...       ...       ...       ...       ...       ...       ...
# 391  1.291973  1.368076  1.288427  1.292315  1.263013  1.283416  1.386572
# 71  -0.966866 -0.191294 -0.984028 -0.974460 -0.963469 -0.998784 -0.524027
# 287  1.192422  0.354587  1.185811  1.187651  1.096415  1.184314  0.629098
# 66  -1.484982 -1.715595 -1.483604 -1.489454 -1.282799 -1.463694 -1.707131
# 85  -1.029932 -1.152630 -1.067422 -1.048163 -1.026773 -1.078769 -1.139563
#
#      2483.372  1328.197  1254.301  ...  837.687   892.475   874.121   \
# 228 -0.721628 -1.145919 -1.142569  ... -1.040947 -1.035275 -1.030146
# 474  0.835998  1.335419  1.339183  ...  1.210396  1.244742  1.230255
# 273  0.689380  1.134285  1.143904  ...  1.127660  1.141946  1.144145
# 285  0.230669  0.708863  0.793438  ...  1.017840  1.000981  1.012044
# 20   0.074469 -0.530351 -0.677694  ... -0.797608 -0.788356 -0.792682
# ..        ...       ...       ...  ...       ...       ...       ...
# 391  1.260518  1.299791  1.283588  ...  1.240678  1.262327  1.258593
# 71   0.045272 -0.937236 -0.998755  ... -0.981073 -0.963380 -0.965990
# 287  0.078464  1.151384  1.184519  ...  1.088064  1.103508  1.098137
# 66  -1.661945 -1.552422 -1.463015  ... -1.292153 -1.282100 -1.279279
# 85  -1.095096 -1.057307 -1.078660  ... -1.024621 -1.025982 -1.027971
#
#      876.781   853.123   884.860   877.969   850.046   845.334   857.355
# 228 -1.033481 -1.032521 -1.034466 -1.029368 -1.031805 -1.039755 -1.031936
# 474  1.231594  1.220015  1.233132  1.230056  1.216652  1.215678  1.224416
# 273  1.144791  1.137959  1.144632  1.144275  1.139449  1.133384  1.144581
# 285  1.010621  1.020728  1.009804  1.008720  1.020247  1.022598  1.018547
# 20  -0.789674 -0.799611 -0.786075 -0.790533 -0.802299 -0.794386 -0.800824
# ..        ...       ...       ...       ...       ...       ...       ...
# 391  1.259826  1.246070  1.264388  1.259422  1.246331  1.244710  1.247542
# 71  -0.963353 -0.978024 -0.959486 -0.964945 -0.978210 -0.975422 -0.977062
# 287  1.097991  1.090781  1.102332  1.098439  1.096154  1.096031  1.091843
# 66  -1.279909 -1.284921 -1.277541 -1.281256 -1.285772 -1.282308 -1.285889
# 85  -1.025618 -1.028104 -1.024180 -1.028601 -1.025806 -1.022977 -1.030241
#
# [382 rows x 44 columns]

# %% [markdown]
# ---

# %%
import json

# %%
with open('ml_gd_fs999.txt', 'w') as file:
     file.write(json.dumps(ml_dicts)) # use `json.loads` to do the reverse

# %%
import json
with open('ml_gd_fs999.txt') as f:
    data = f.read()
    
ml_dicts = json.loads(data)

with open('base_gd.txt') as f:
    data = f.read()
    
baseDict = json.loads(data)
baseDict['lr'].keys()
# Out:
# dict_keys(['lr, all'])

# %%
print(baseDict['lr'].keys()    )
print(ml_dicts['lr'].keys()    )
# Out:
# dict_keys(['lr, all'])
# dict_keys(['lr,1', 'lr,2', 'lr,3', 'lr,4', 'lr,5', 'lr,6', 'lr,7', 'lr,8', 'lr,9', 'lr,10', 'lr,11', 'lr,12', 'lr,13', 'lr,14', 'lr,15', 'lr,16', 'lr,17', 'lr,18', 'lr,19', 'lr,20', 'lr,21', 'lr,22', 'lr,23', 'lr,24', 'lr,25', 'lr,26', 'lr,27', 'lr,28', 'lr,29', 'lr,30', 'lr,31', 'lr,32', 'lr,33', 'lr,34', 'lr,35', 'lr,36', 'lr,37', 'lr,38', 'lr,39', 'lr,40', 'lr,41', 'lr,42', 'lr,43', 'lr,44'])

# %%
from source.calculate_jack import jack_SD # importing the baseline code from source.basline file

# %%
arr_all = []
for m, d in zip (models, ml_dicts.keys()):
    acc_arr = [] 
    sd_arr = [] 

    # print(ml_dicts[d])
    for key in ml_dicts[d].keys():
        acc_arr.append(ml_dicts[d][key][ 'tot_acc' ]) # append total accuracy to an array
        sd_train = jack_SD(np.zeros( len(ml_dicts[d][key][ 'jack_train' ]) ), ml_dicts[d][key][ 'jack_train' ])[0]
        sd_test = jack_SD(np.zeros( len(ml_dicts[d][key][ 'jack_test' ]) ), ml_dicts[d][key][ 'jack_test' ])[0]
        sd = np.sqrt( np.array((sd_train**2)) + np.array((sd_test**2)))
        sd_arr.append(sd) # append sd_arr to an array
    arr_all.append([ list(ml_dicts[d].keys()), acc_arr, sd_arr])

# %%
colors = ['blue', 'purple', 'green', 'orange', 'red', 'brown']
plt.figure(figsize=(15, 7))
plt.title( "Precision  for different features with the SD", fontweight ='bold', fontsize =12)
plt.xlabel("Features", fontweight ='bold', fontsize =12)
plt.ylabel("Precision", fontweight ='bold', fontsize =12)

count = 0
n = len(colors)-1

space = []
tickFeat = []

for result, model, color in zip(arr_all, models, colors):
    a = np.linspace(n*count, n*(1+count)-2,44)
    print(a)
    space.extend(a)
    tickFeat.extend(result[0])
    plt.errorbar( a, result[1], result[2], fmt='o', label =model[1], color = color)
    count += 1

plt.xticks(space, tickFeat, rotation = 'vertical',  fontsize =12)
plt.ylim(.2, 1)
plt.legend()

plt.show()
# Out:
# [0.         0.06976744 0.13953488 0.20930233 0.27906977 0.34883721
#  0.41860465 0.48837209 0.55813953 0.62790698 0.69767442 0.76744186
#  0.8372093  0.90697674 0.97674419 1.04651163 1.11627907 1.18604651
#  1.25581395 1.3255814  1.39534884 1.46511628 1.53488372 1.60465116
#  1.6744186  1.74418605 1.81395349 1.88372093 1.95348837 2.02325581
#  2.09302326 2.1627907  2.23255814 2.30232558 2.37209302 2.44186047
#  2.51162791 2.58139535 2.65116279 2.72093023 2.79069767 2.86046512
#  2.93023256 3.        ]

# %%
[5,4], [541]
# Out:
# ([5, 4], [541])

# %%
arr_diff_all = []

for m, m_key in zip (models, ml_dicts.keys()):
    acc_diff_arr = [] 
    sd_diff_arr = [] 
    for f_key in ml_dicts[m_key].keys():
        value = f_key.split(',')
        acc_diff_arr.append( ml_dicts[m_key][f_key][ 'tot_acc' ] - baseDict['lr']['lr, all'][ 'tot_acc' ]  )

        sd_train = jack_SD( baseDict['lr']['lr, all'][ 'jack_train' ], ml_dicts[m_key][f_key]['jack_train'] )[0]
        sd_test = jack_SD(  baseDict['lr']['lr, all'][ 'jack_test' ],  ml_dicts[m_key][f_key]['jack_test']   )[0]

        sd = np.sqrt( np.array((sd_train**2)) + np.array((sd_test**2)))
        sd_diff_arr.append(sd) # append sd_arr to an array
    arr_diff_all.append([ list(ml_dicts[m_key].keys()), acc_diff_arr, sd_diff_arr])

# %%
colors = ['blue', 'purple', 'green', 'orange', 'red', 'brown']
plt.figure(figsize=(15, 7))
plt.title( "Precision  differences for ML methods versus LR_all for feature setsD", fontweight ='bold', fontsize =12)
plt.xlabel("Features", fontweight ='bold', fontsize =12)
plt.ylabel("Precision  difference", fontweight ='bold', fontsize =12)

count = 0
n = len(colors)-0.5
space = []
tickFeat = []

for result, model, color in zip(arr_diff_all, models, colors):
    a = np.linspace(n*count, n*(1+count)-2,44)
    space.extend(a)
    tickFeat.extend(result[0])
    plt.errorbar( a, result[1], result[2], fmt='o', label =model[1], color = color)
    count += 1
    
plt.plot(np.array(space), np.zeros(44*1), color = 'Black')        
plt.xticks(space, tickFeat, rotation = 'vertical',  fontsize =12)
plt.ylim(-.5, 1)
plt.legend()

plt.show()

# %%
print(1)
